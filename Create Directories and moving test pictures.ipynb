# %%
import os

# %%
CATEGORIES = ['Apple___Apple_scab', 'Apple___Black_rot',
       'Apple___Cedar_apple_rust', 'Apple___healthy',
       'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
       'Corn_(maize)___Common_rust_',
       'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy',
       'Grape___Black_rot', 'Grape___Esca_(Black_Measles)',
       'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy',
       'Potato___Early_blight', 'Potato___Late_blight',
       'Potato___healthy', 'Tomato___Bacterial_spot',
       'Tomato___Early_blight', 'Tomato___Late_blight',
       'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot',
       'Tomato___Spider_mites Two-spotted_spider_mite',
       'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
       'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
#Makew folders 
for c in CATEGORIES:
#     os.mkdir("N:/RiceDetectionGithub/Segmented/Processed/"+c)
    os.mkdir("/home/mazumder_8100/crowdAi/test/"+c)

# %%
os.mkdir('N:/Rice Detection/PlantVillage CrodAi-Labeled/TestPicturesColor/A')

# %%
# rootDir = "N:/Rice Detection/PlantVillage CrodAi-Labeled/TestPicturesColor"
rootDir = "/home/mazumder_8100/crowdAi/test"

# srcDir = "N:/Rice Detection/PlantVillage CrodAi-Labeled/color"
srcDir = "/home/mazumder_8100/crowdAi/seg/segmented"

# %%
print(rootDir)
# Out:
# /home/mazumder_8100/crowdAi/test

# %%
import shutil

# %%
for c in CATEGORIES:
    dira = rootDir + '/' + c
    dirSrc = srcDir + '/' + c
    print(dirSrc)
    for a in os.listdir(dirSrc)[:10]:
        print(a)
        dirSrc_img = dirSrc + '/' + a
        shutil.move(dirSrc_img, dira)
# Out:
# /home/mazumder_8100/crowdAi/seg/segmented/Apple___Apple_scab
# 453b09e4-6469-47f9-8599-f87e1d6eddf3___FREC_Scab 3048_final_masked.jpg
# 0db71c1d-93d7-4481-b0d0-b73f995131a9___FREC_Scab 2976_final_masked.jpg
# 83dc6270-1c10-4c76-a1a2-6b562fcb4e4c___FREC_Scab 3478_final_masked.jpg
# 7edff180-8238-44d7-bba1-07749e649dae___FREC_Scab 3071_final_masked.jpg
# de8933ae-509d-48ae-8cd7-9097ad1e6d2d___FREC_Scab 3307_final_masked.jpg
# 3c27bbd7-b305-4ab0-8a85-5061363cf632___FREC_Scab 3183_final_masked.jpg
# f141c7f9-66b7-4052-b5c7-db3df1a894f2___FREC_Scab 3261_final_masked.jpg
# 0ea78733-9404-4536-8793-a108c66269b3___FREC_Scab 3145_final_masked.jpg
# a31b7944-c213-4b83-a586-004d0522e355___FREC_Scab 3341_final_masked.jpg
# e0bf6219-02d8-4255-88e2-a99afb1ad355___FREC_Scab 3515_final_masked.jpg
# /home/mazumder_8100/crowdAi/seg/segmented/Apple___Black_rot
# 26b71abd-6648-4d92-a36d-92353bc09966___JR_FrgE.S 2899_final_masked.jpg
# ...

# %%
#  for a in os.listdir(dirSrc)[:10]:
#         print(a)
# Out:
# 000146ff-92a4-4db6-90ad-8fce2ae4fddd___GH_HL Leaf 259.1.JPG
# 000bf685-b305-408b-91f4-37030f8e62db___GH_HL Leaf 308.1.JPG
# 0031da2a-8edd-468f-a8b1-106657717a32___RS_HL 0105.JPG
# 003944fc-3b99-4a0f-9ed4-0e07352fd8b3___RS_HL 9844.JPG
# 00bce074-967b-4d50-967a-31fdaa35e688___RS_HL 0223.JPG
# 014b5e19-7917-4d76-b632-b5dd31d999ec___RS_HL 9640.JPG
# 01700b46-3800-46c6-ab81-09a5f50af525___RS_HL 0108.JPG
# 0172e56c-8bb8-4e75-8ac7-509df81393e8___RS_HL 0580.JPG
# 017a4026-813a-4983-887a-4052bb78c397___RS_HL 0218.JPG
# 0184dc6b-bfc1-4515-ac59-bbadaf524e1a___GH_HL Leaf 422.1.JPG
