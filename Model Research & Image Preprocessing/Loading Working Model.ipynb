# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
##Loading Model
model = load_model("/home/mazumder_8100/crowdAi/models/model(MobileNet).hdf5")

print("MODEL-LOADED")
# Out:
# MODEL-LOADED

# %%
# class_indices = {'Apple___Apple_scab': 0, 'Apple___Black_rot': 1, 'Apple___Cedar_apple_rust': 2, 'Apple___healthy': 3, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 4, 'Corn_(maize)___Common_rust_': 5, 'Corn_(maize)___Northern_Leaf_Blight': 6, 'Corn_(maize)___healthy': 7, 'Grape___Black_rot': 8, 'Grape___Esca_(Black_Measles)': 9, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 10, 'Grape___healthy': 11, 'NotLeaf': 12, 'Potato___Early_blight': 13, 'Potato___Late_blight': 14, 'Potato___healthy': 15, 'Tomato___Bacterial_spot': 16, 'Tomato___Early_blight': 17, 'Tomato___Late_blight': 18, 'Tomato___Leaf_Mold': 19, 'Tomato___Septoria_leaf_spot': 20, 'Tomato___Spider_mites Two-spotted_spider_mite': 21, 'Tomato___Target_Spot': 22, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 23, 'Tomato___Tomato_mosaic_virus': 24, 'Tomato___healthy': 25}
#Create Labels
# labels = (class_indices)
# labels = dict((v,k) for k,v in labels.items())

# %%
#Labels
labels = {0: 'Apple___Apple_scab',
 1: 'Apple___Black_rot',
 2: 'Apple___Cedar_apple_rust',
 3: 'Apple___healthy',
 4: 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
 5: 'Corn_(maize)___Common_rust_',
 6: 'Corn_(maize)___Northern_Leaf_Blight',
 7: 'Corn_(maize)___healthy',
 8: 'Grape___Black_rot',
 9: 'Grape___Esca_(Black_Measles)',
 10: 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
 11: 'Grape___healthy',
 12: 'NotLeaf',
 13: 'Potato___Early_blight',
 14: 'Potato___Late_blight',
 15: 'Potato___healthy',
 16: 'Tomato___Bacterial_spot',
 17: 'Tomato___Early_blight',
 18: 'Tomato___Late_blight',
 19: 'Tomato___Leaf_Mold',
 20: 'Tomato___Septoria_leaf_spot',
 21: 'Tomato___Spider_mites Two-spotted_spider_mite',
 22: 'Tomato___Target_Spot',
 23: 'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
 24: 'Tomato___Tomato_mosaic_virus',
 25: 'Tomato___healthy'}

# %% [markdown]
# ## Loading Image

# %%
from keras.applications.mobilenet import preprocess_input
from keras.preprocessing import image
import numpy as np
import keras

# %%
#Image Preprocessing
def prepare_image(file):
    img_path = ''
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
#Prepare and Predict Image
preprocessed_image = prepare_image("/home/mazumder_8100/crowdAi/CustomDataset/Custom-Train-Test(color)/Test/Apple___Apple_scab/08c42d78-aa7b-4106-b0c1-b260f898dcba___FREC_Scab 3151.JPG")
predictions = model.predict(preprocessed_image)

# %%
#Predicted class indicies
predicted_class_indices=np.argmax(predictions,axis=1)
predicted_class_indices
# Out:
# array([0])

# %%
labels[int(predicted_class_indices)]
# Out:
# 'Apple___Apple_scab'

# %%
def MakePred(image_dir):
    #Prepare and Predict Image
    preprocessed_image = prepare_image(image_dir)
    predictions = model.predict(preprocessed_image)
    
    #Predicted class indicies
    predicted_class_indices=np.argmax(predictions,axis=1)
    predicted_class_indices
    
#     print(labels[int(predicted_class_indices)])
    return str(labels[int(predicted_class_indices)])

# %%
import os

# %%
rootDir = '/home/mazumder_8100/crowdAi/CustomDataset/Custom-Train-Test(color)/Test'

# %%
#Testing Images
Test_parent = os.listdir(rootDir)

for test in Test_parent:
    images = os.listdir(rootDir+'/'+test)
    test_images_count = len (images)
    print('Testing-',test, ' Imag =', test_images_count)
    counter = 0
    for img in images:
        img_dir = rootDir + '/' + test + '/' + img
        res = MakePred(img_dir)
        print(res)
        if res == test:
            counter+= 1
    print("Correct Result:",counter)
# Out:
# Testing- Tomato___Early_blight  Imag = 10
# Tomato___Early_blight
# Tomato___Late_blight
# Tomato___Early_blight
# Tomato___Early_blight
# Tomato___Early_blight
# Tomato___Late_blight
# Tomato___Target_Spot
# Tomato___Bacterial_spot
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Early_blight
# Correct Result: 5
# Testing- Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot  Imag = 10
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Northern_Leaf_Blight
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Correct Result: 9
# Testing- Apple___healthy  Imag = 10
# Apple___healthy
# Apple___healthy
# Apple___healthy
# Apple___healthy
# Apple___healthy
# Apple___healthy
# Apple___healthy
# Apple___healthy
# Apple___healthy
# Apple___healthy
# Correct Result: 10
# Testing- Corn_(maize)___Northern_Leaf_Blight  Imag = 10
# Corn_(maize)___Northern_Leaf_Blight
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Northern_Leaf_Blight
# Corn_(maize)___Northern_Leaf_Blight
# Corn_(maize)___Northern_Leaf_Blight
# Corn_(maize)___Northern_Leaf_Blight
# Corn_(maize)___Northern_Leaf_Blight
# Corn_(maize)___Northern_Leaf_Blight
# Corn_(maize)___Northern_Leaf_Blight
# Corn_(maize)___Northern_Leaf_Blight
# Correct Result: 9
# Testing- Corn_(maize)___healthy  Imag = 10
# Corn_(maize)___healthy
# Corn_(maize)___healthy
# Corn_(maize)___healthy
# Corn_(maize)___healthy
# Corn_(maize)___healthy
# Corn_(maize)___healthy
# Corn_(maize)___healthy
# Corn_(maize)___healthy
# Corn_(maize)___healthy
# Corn_(maize)___healthy
# Correct Result: 10
# Testing- Apple___Black_rot  Imag = 10
# Tomato___Target_Spot
# Apple___Black_rot
# Apple___Black_rot
# Apple___Black_rot
# Apple___Black_rot
# Apple___Black_rot
# Apple___Black_rot
# Apple___Black_rot
# Apple___Black_rot
# Potato___Late_blight
# Correct Result: 8
# Testing- Grape___Black_rot  Imag = 10
# Grape___Black_rot
# Grape___Black_rot
# Grape___Black_rot
# Grape___Black_rot
# Grape___Black_rot
# Grape___Black_rot
# Grape___Black_rot
# Grape___Black_rot
# Grape___Black_rot
# Grape___Black_rot
# Correct Result: 10
# Testing- Tomato___Tomato_Yellow_Leaf_Curl_Virus  Imag = 10
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Correct Result: 9
# Testing- Grape___healthy  Imag = 10
# Grape___healthy
# Grape___healthy
# Grape___healthy
# Grape___healthy
# Grape___healthy
# Grape___healthy
# Grape___healthy
# Grape___healthy
# Grape___healthy
# Grape___healthy
# Correct Result: 10
# Testing- Tomato___Bacterial_spot  Imag = 10
# Tomato___Bacterial_spot
# Tomato___Bacterial_spot
# Tomato___Bacterial_spot
# Tomato___Bacterial_spot
# Tomato___Bacterial_spot
# Tomato___Bacterial_spot
# Tomato___Bacterial_spot
# Tomato___Bacterial_spot
# Tomato___Bacterial_spot
# Tomato___Bacterial_spot
# Correct Result: 10
# Testing- Grape___Esca_(Black_Measles)  Imag = 10
# Grape___Esca_(Black_Measles)
# Grape___Esca_(Black_Measles)
# Grape___Esca_(Black_Measles)
# Grape___Esca_(Black_Measles)
# Grape___Esca_(Black_Measles)
# Grape___Esca_(Black_Measles)
# Grape___Esca_(Black_Measles)
# Grape___Esca_(Black_Measles)
# Grape___Esca_(Black_Measles)
# Grape___Black_rot
# Correct Result: 9
# Testing- NotLeaf  Imag = 2
# NotLeaf
# NotLeaf
# Correct Result: 2
# Testing- Potato___Late_blight  Imag = 10
# Potato___Late_blight
# Potato___Late_blight
# Potato___Late_blight
# Potato___Late_blight
# Potato___Late_blight
# Potato___Late_blight
# Potato___Late_blight
# Potato___Late_blight
# Potato___Late_blight
# Potato___Late_blight
# Correct Result: 10
# Testing- Grape___Leaf_blight_(Isariopsis_Leaf_Spot)  Imag = 10
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Correct Result: 10
# Testing- Tomato___Late_blight  Imag = 10
# Tomato___Late_blight
# Tomato___Late_blight
# Tomato___Late_blight
# Tomato___Late_blight
# Tomato___Late_blight
# Tomato___Late_blight
# Tomato___Late_blight
# Tomato___Late_blight
# Tomato___Late_blight
# Tomato___Late_blight
# Correct Result: 10
# Testing- Tomato___healthy  Imag = 10
# Tomato___healthy
# Tomato___healthy
# Tomato___healthy
# Tomato___healthy
# Tomato___healthy
# Tomato___healthy
# Tomato___healthy
# Tomato___healthy
# Tomato___healthy
# Tomato___healthy
# Correct Result: 10
# Testing- Tomato___Spider_mites Two-spotted_spider_mite  Imag = 10
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Correct Result: 10
# Testing- Tomato___Target_Spot  Imag = 10
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Target_Spot
# Tomato___Target_Spot
# Tomato___Target_Spot
# Tomato___Target_Spot
# Tomato___Target_Spot
# Tomato___Target_Spot
# Tomato___Target_Spot
# Tomato___Target_Spot
# Tomato___Target_Spot
# Correct Result: 9
# Testing- Apple___Cedar_apple_rust  Imag = 10
# Apple___Cedar_apple_rust
# Apple___Cedar_apple_rust
# Apple___Cedar_apple_rust
# Apple___Cedar_apple_rust
# Apple___Cedar_apple_rust
# Apple___Cedar_apple_rust
# Apple___Cedar_apple_rust
# Apple___Cedar_apple_rust
# Apple___Cedar_apple_rust
# Apple___Cedar_apple_rust
# Correct Result: 10
# Testing- Corn_(maize)___Common_rust_  Imag = 10
# Corn_(maize)___Common_rust_
# Corn_(maize)___Common_rust_
# Corn_(maize)___Common_rust_
# Corn_(maize)___Common_rust_
# Corn_(maize)___Common_rust_
# Corn_(maize)___Common_rust_
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Common_rust_
# Corn_(maize)___Common_rust_
# Corn_(maize)___Common_rust_
# Correct Result: 9
# Testing- Tomato___Septoria_leaf_spot  Imag = 10
# Tomato___Late_blight
# Tomato___Septoria_leaf_spot
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Septoria_leaf_spot
# Tomato___Septoria_leaf_spot
# Tomato___Target_Spot
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Septoria_leaf_spot
# Tomato___Septoria_leaf_spot
# Tomato___Late_blight
# Correct Result: 5
# Testing- Tomato___Leaf_Mold  Imag = 10
# Tomato___Leaf_Mold
# Tomato___Leaf_Mold
# Tomato___Leaf_Mold
# Tomato___Leaf_Mold
# Tomato___Leaf_Mold
# Tomato___Leaf_Mold
# Tomato___Leaf_Mold
# Tomato___Leaf_Mold
# Tomato___Leaf_Mold
# Tomato___Leaf_Mold
# Correct Result: 10
# Testing- Tomato___Tomato_mosaic_virus  Imag = 10
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Spider_mites Two-spotted_spider_mite
# Correct Result: 0
# Testing- Potato___healthy  Imag = 10
# Potato___healthy
# Potato___healthy
# Tomato___Spider_mites Two-spotted_spider_mite
# Potato___healthy
# Tomato___Spider_mites Two-spotted_spider_mite
# Potato___healthy
# Potato___healthy
# Potato___healthy
# Potato___healthy
# Potato___healthy
# Correct Result: 8
# Testing- Potato___Early_blight  Imag = 10
# Potato___Late_blight
# Potato___Early_blight
# Potato___Early_blight
# Tomato___Early_blight
# Potato___Early_blight
# Potato___Early_blight
# Potato___Early_blight
# Potato___Early_blight
# Potato___Early_blight
# Potato___Early_blight
# Correct Result: 8
# Testing- Apple___Apple_scab  Imag = 10
# Apple___Apple_scab
# Apple___Cedar_apple_rust
# Apple___Apple_scab
# Apple___Apple_scab
# Apple___healthy
# Apple___Apple_scab
# Apple___healthy
# Apple___Apple_scab
# Apple___Black_rot
# Apple___healthy
# Correct Result: 5
